# %% [markdown]
# # __Choosing a Neighborhood__

# %%
import json
import folium
import requests
import numpy as np
import pandas as pd
import matplotlib.cm as cm
import matplotlib.colors as colors
from sklearn.cluster import KMeans
from geopy.geocoders import Nominatim
from pandas.io.json import json_normalize

# %%
# To show all rows and columns
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %% [markdown]
# The list of neighborhoods within a given radius was found using the online tool at [Freeaptools.com.](https://www.freemaptools.com/find-cities-and-towns-inside-radius.htm) It made it easy to export the following .csv file, which contains all the cities and towns within a 10 mile radius of East Fishkill, NY, USA.

# %%
df = pd.read_csv('Neighborhoods.csv')

# %%
df.head()
# Out:
#   Hopewell Junction
# 0     Hillside Lake
# 1     East Fishkill
# 2   Fishkill Plains
# 3            Lomala
# 4     Swartoutville

# %% [markdown]
# ##### There are two things we need to do to this dataframe. One, change the column header, and two, append ", NY" to each row. This is for the input to geocoder to get the latitude and longitude of each neighborhood.

# %%
df.rename(columns = {'Hopewell Junction' : 'Neighborhood'}, inplace = True)
df.head()
# Out:
#       Neighborhood
# 0    Hillside Lake
# 1    East Fishkill
# 2  Fishkill Plains
# 3           Lomala
# 4    Swartoutville

# %% [markdown]
# ##### We'll append ", NY" as we read each row from the dataframe into geocoder.

# %%
# Create columns in the dataframe for the latitude and longitude
df['Latitude'] = ''
df['Longitude'] = ''

# Create the geocoder object
geolocator = Nominatim(user_agent="ny_explorer")

# Loop through neighborhoods, requesting the latitude and longitude for each one
for index, neighborhood in df.iterrows():
    address = '{}, NY'.format(neighborhood[0])    
    location = geolocator.geocode(address)
    df.iloc[index]['Latitude'] = location.latitude
    df.iloc[index]['Longitude'] = location.longitude

df.head()
# Out:
#       Neighborhood Latitude Longitude
# 0    Hillside Lake  41.6185  -73.7935
# 1    East Fishkill  41.5533  -73.7956
# 2  Fishkill Plains  41.6072  -73.8302
# 3           Lomala  41.5598  -73.8412
# 4    Swartoutville  41.5634   -73.849

# %% [markdown]
# ### Create initial Folium map:

# %%
# Latitude and longitude of new workplace
latitude = 41.58
longitude = -73.81


# Create Folium object
map = folium.Map(location=[latitude, longitude], zoom_start=7)

# Add markers to map
for lat, lng, label in zip(df['Latitude'], df['Longitude'], df['Neighborhood']):
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map)  
    
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ##### If we zoom out, we see we have some outliers. We'll identify these by eye and remove them so they don't interfere with the classification.

# %%
df.shape
# Out:
# (95, 3)

# %%
outliers = ['Colonial Heights', 'Chelsea', 'Crown Heights', 'Milton', 'Clove', 'Berkshire Terrace']

for index, neighborhood in df.iterrows():
    for outlier in outliers:
        if neighborhood[0] == outlier:
            df.drop(index, inplace = True)

df.shape
# Out:
# (89, 3)

# %% [markdown]
#  ##### This means we have 89 neighborhoods to choose from. That's a lot.

# %%
# Now we'll redraw the map without the outliers
# Recreate Folium object
map = folium.Map(location=[latitude, longitude], zoom_start=10.4)

# Add markers to map
for lat, lng, label in zip(df['Latitude'], df['Longitude'], df['Neighborhood']):
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map)  
    
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Using Foursquare

# %%
# Foursquare credentials
CLIENT_ID = '4V4LEON5PH4AQBIAYOZ0OZRGNLS35NC1LKAFAALX5YQ0PLW4'
CLIENT_SECRET = 'SUD5EDXWNSBLVCCCNWLXRZRTCKVOV1UCKOD4U1NIQA2XCTLM' 
VERSION = '20180605'

# %%
# Foursquare request parameters
names, latitudes, longitudes = df['Neighborhood'], df['Latitude'], df['Longitude']
radius = 500
LIMIT = 100

venues_list=[]
for name, lat, lng in zip(names, latitudes, longitudes):

    # create the API request URL
    url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
        CLIENT_ID, 
        CLIENT_SECRET, 
        VERSION, 
        lat, 
        lng, 
        radius, 
        LIMIT)

    # make the GET request
    results = requests.get(url).json()["response"]['groups'][0]['items']

    # return only relevant information for each nearby venue
    venues_list.append([(
        name, 
        lat, 
        lng, 
        v['venue']['name'],   
        v['venue']['categories'][0]['name']) for v in results])

venues0 = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
venues0.columns = ['Neighborhood', 
              'Latitude', 
              'Longitude', 
              'Venue', 
              'Venue Category']

venues0.head()
# Out:
#     Neighborhood   Latitude  Longitude  \
# 0  East Fishkill  41.553331 -73.795621
# 1  East Fishkill  41.553331 -73.795621
# 2  East Fishkill  41.553331 -73.795621
# 3  East Fishkill  41.553331 -73.795621
# 4  East Fishkill  41.553331 -73.795621
#
#                                         Venue           Venue Category
# 0               Plated Modern American Bistro  New American Restaurant
# 1  East Fishkill Provisions / Smoke Haus Deli                BBQ Joint
# 2        Inn At Arbor Ridge Hopewell Junction                    Hotel
# 3                                 Mr G's Deli            Deli / Bodega
# 4                                       Shell              Gas Station

# %%
# We'll create a copy to lower the number of Foursquare API calls
venues = venues0.copy()
venues.shape
# Out:
# (453, 5)

# %%
venues.head()
# Out:
#     Neighborhood   Latitude  Longitude  \
# 0  East Fishkill  41.553331 -73.795621
# 1  East Fishkill  41.553331 -73.795621
# 2  East Fishkill  41.553331 -73.795621
# 3  East Fishkill  41.553331 -73.795621
# 4  East Fishkill  41.553331 -73.795621
#
#                                         Venue           Venue Category
# 0               Plated Modern American Bistro  New American Restaurant
# 1  East Fishkill Provisions / Smoke Haus Deli                BBQ Joint
# 2        Inn At Arbor Ridge Hopewell Junction                    Hotel
# 3                                 Mr G's Deli            Deli / Bodega
# 4                                       Shell              Gas Station

# %% [markdown]
# ##### There were 453 results returned. Let's group them by neighborhood.

# %%
count = venues.groupby('Neighborhood').agg(Count = pd.NamedAgg(column = 'Venue', aggfunc = 'count'))
count
# Out:
#                      Count
# Neighborhood
# Allen Corners            1
# Arlington                6
# Arthursburg             10
# Beacon                  42
# Beacon Hills             3
# Beekman                  2
# Billings                 9
# Brinckerhoff             2
# Brockway                 3
# Camby                    1
# Carmel                   9
# Carmel Park Estates      1
# Castle Point             2
# Cedar Cliff              1
# Clark Heights            2
# Dennytown                2
# Diddell                  2
# East Fishkill            5
# Fishkill                33
# Fishkill Plains         19
# Freedom Plains           9
# Glenham                  2
# Green Haven              3
# Groveville               2
# Highland Landing         2
# Hughsonville             5
# Hurd Corners             1
# Kent Cliffs              2
# Kent Corners             2
# Kent Hills               7
# Knapps Corner           51
# Lake Carmel              5
# Lattintown               1
# MacDonnell Heights       3
# Manchester Bridge        8
# Marlboro                 9
# Meads Corners            1
# Middle Hope              4
# Moores Mill              1
# Myers Corner             1
# New Hackensack           3
# New Hamburg              6
# Newburgh                26
# North Highland           5
# Noxon                    2
# Oakes                    2
# Patterson                5
# Pawling                 21
# Pecksville               3
# Pleasant Valley         16
# Poughkeepsie            18
# Poughquag                1
# Red Oaks Mill            1
# Rochdale                 2
# Rombout Ridge            1
# Rudco                    3
# Spackenkill              4
# Stormville               4
# Swartoutville            2
# Sylvan Lake              3
# Timothy Heights          1
# Titusville               4
# Towners                  1
# Verbank                  5
# Verbank Village          1
# Wappingers Falls        29
# West Patterson           1
# West Pawling             2
# Wiccopee                 4
# Woodinville              3

# %% [markdown]
# ##### It looks like there are many neighborhoods with only a few restaurants. Let's sort the dataframe and remove those with less than 10.

# %%
count.sort_values(by = 'Count', ascending = False, inplace = True)
count.reset_index(inplace = True)

# Keep a list of neighborhoods to keep and drop all others
keep = []
for index, row in count.iterrows():
    if row[1] < 10:
        count.drop(index, inplace = True)
    else:
        keep.append(row[0])
    
     
count
# Out:
#        Neighborhood  Count
# 0     Knapps Corner     51
# 1            Beacon     42
# 2          Fishkill     33
# 3  Wappingers Falls     29
# 4          Newburgh     26
# 5           Pawling     21
# 6   Fishkill Plains     19
# 7      Poughkeepsie     18
# 8   Pleasant Valley     16
# 9       Arthursburg     10

# %% [markdown]
# ##### This has reduced our neighborhood search from 89 neighborhoods to 10. Now, we'll make the changes to the original dataframe and convert it to one hot encoding.

# %%
for index, row in venues.iterrows():
    flag = False
    for k in keep:
        if k == row[0]:
            flag = True
    
    if flag == False:
        venues.drop(index, inplace = True)
        
venues.shape
# Out:
# (265, 5)

# %%
# one hot encoding
onehot = pd.get_dummies(venues[['Venue Category']], prefix="", prefix_sep="")

# add neighborhood column back to dataframe
onehot['Neighborhood'] = venues['Neighborhood'] 

# move neighborhood column to the first column
fixed_columns = [onehot.columns[-1]] + list(onehot.columns[:-1])
onehot = onehot[fixed_columns]

onehot.head()
# Out:
#       Neighborhood  Accessories Store  American Restaurant  Arcade  \
# 5  Fishkill Plains                  0                    0       0
# 6  Fishkill Plains                  0                    0       0
# 7  Fishkill Plains                  0                    0       0
# 8  Fishkill Plains                  0                    0       0
# 9  Fishkill Plains                  0                    0       0
#
#    Asian Restaurant  Automotive Shop  BBQ Joint  Bagel Shop  Bakery  Bank  \
# 5                 0                0          0           0       0     0
# 6                 0                0          0           0       0     0
# 7                 0                0          0           0       0     0
# 8                 0                0          0           0       0     0
# 9                 0                0          0           0       0     0
#
#    Bar  Beer Garden  Big Box Store  Boat or Ferry  Bookstore  Boutique  \
# 5    0            0              0              0          0         0
# 6    0            0              0              0          0         0
# 7    0            0              0              0          0         0
# 8    0            0              0              0          0         0
# 9    0            0              0              0          0         0
#
#    Breakfast Spot  Brewery  Burger Joint  Café  Candy Store  \
# 5               0        0             0     0            0
# 6               0        0             0     0            0
# 7               0        0             0     0            0
# 8               0        0             0     0            0
# 9               0        0             0     0            0
#
#    Chinese Restaurant  Clothing Store  Coffee Shop  Concert Hall  \
# 5                   0               0            0             0
# 6                   0               0            0             0
# 7                   0               0            0             0
# 8                   0               0            0             0
# 9                   0               0            0             0
#
#    Construction & Landscaping  Convenience Store  Cosmetics Shop  Creperie  \
# 5                           0                  0               0         0
# 6                           0                  0               0         0
# 7                           0                  0               0         0
# 8                           0                  1               0         0
# 9                           0                  0               0         0
#
#    Dance Studio  Deli / Bodega  Department Store  Dessert Shop  Diner  \
#
# 6                 0           0                 1              0
# 7                 0           0                 0              0
# 8                 0           0                 0              0
# 9                 0           0                 0              0
#
#    Tex-Mex Restaurant  Theater  Thrift / Vintage Store  Toy / Game Store  \
# 5                   0        0                       0                 0
# 6                   0        0                       0                 0
# 7                   0        0                       0                 0
# 8                   0        0                       0                 0
# 9                   0        0                       0                 0
#
#    Train Station  Video Game Store  Vietnamese Restaurant  Wine Bar  \
# 5              0                 0                      0         0
# 6              0                 0                      0         0
# 7              0                 0                      0         0
# 8              0                 0                      0         0
# 9              0                 0                      0         0
#
#    Wine Shop  Wings Joint  Women's Store  Yoga Studio
# 5          0            0              0            0
# 6          0            0              0            0
# 7          0            0              0            0
# 8          0            0              0            0
# 9          0            0              0            0

# %%
# Pull list of categories
categories = onehot.columns.values.tolist()

# To simplify the process of finding just the restaurants, let's find all of them 
# with 'Restaurant' in the category type.
keep = []
for category in categories:
    if category.find('Restaurant') != -1:
        keep.append(category)

edit_onehot = onehot.drop(keep, axis = 1)
        
edit_onehot.head()

# The rest will be added to the keep list by eye. 
# (in practice, a list of keywords could easily be placed in the above for loop)
# Out:
#       Neighborhood  Accessories Store  Arcade  Automotive Shop  BBQ Joint  \
# 5  Fishkill Plains                  0       0                0          0
# 6  Fishkill Plains                  0       0                0          0
# 7  Fishkill Plains                  0       0                0          0
# 8  Fishkill Plains                  0       0                0          0
# 9  Fishkill Plains                  0       0                0          0
#
#    Bagel Shop  Bakery  Bank  Bar  Beer Garden  Big Box Store  Boat or Ferry  \
# 5           0       0     0    0            0              0              0
# 6           0       0     0    0            0              0              0
# 7           0       0     0    0            0              0              0
# 8           0       0     0    0            0              0              0
# 9           0       0     0    0            0              0              0
#
#    Bookstore  Boutique  Breakfast Spot  Brewery  Burger Joint  Café  \
# 5          0         0               0        0             0     0
# 6          0         0               0        0             0     0
# 7          0         0               0        0             0     0
# 8          0         0               0        0             0     0
# 9          0         0               0        0             0     0
#
#    Candy Store  Clothing Store  Coffee Shop  Concert Hall  \
# 5            0               0            0             0
# 6            0               0            0             0
# 7            0               0            0             0
# 8            0               0            0             0
# 9            0               0            0             0
#
#    Construction & Landscaping  Convenience Store  Cosmetics Shop  Creperie  \
# 5                           0                  0               0         0
# 6                           0                  0               0         0
# 7                           0                  0               0         0
# 8                           0                  1               0         0
# 9                           0                  0               0         0
#
#    Dance Studio  Deli / Bodega  Department Store  Dessert Shop  Diner  \
# 5             0              0                 0             0      0
# 6             0              0                 0             0      0
# 7             0              0                 0             0      0
# 8             0              0                 0             0      0
# 9             0              0                 0             0      0
#
#    Discount Store  Dive Bar  Donut Shop  Dry Cleaner  Flea Market  \
# 5               0         0           0            0            0
# 6               0         0           0            0            0
# 7               0         0           0            0            0
# 8               0         0           0            0            0
# 9               0         0           1            0            0
#
#    Flower Shop  Food  Furniture / Home Store  Gas Station  Gastropub  Gay Bar  \
# 5            0     0                       0            0          0        0
# 6            0     0                       0            0          0        0
# 7            0     0                       0            0          0        0
# 8            0     0                       0            0          0        0
# 9            0     0                       0            0          0        0
#
#    Gift Shop  Gourmet Shop  Gym  Gym / Fitness Center  Harbor / Marina  \
# 5          0             0    0                     0                0
# 6          0             0    0                     0                0
# 7          0             0    0                     0                0
# 8          0             0    0                     0                0
# 9          0             0    0                     0                0
#
#    Hardware Store  Health Food Store  Home Service  Hotel  Ice Cream Shop  \
# 5               0                  0             0      0               0
# 6               0                  0             0      0               0
# 7               0                  0             0      0               0
# 8               0                  0             0      0               0
# 9               0                  0             0      0               0
#
#    Indie Movie Theater  Irish Pub  Jewelry Store  Kids Store  Lawyer  \
# 5                    0          0              0           0       0
# 6                    0          0              0           0       0
# 7                    0          0              0           0       0
# 8                    0          0              0           0       0
# 9                    0          0              0           0       0
#
#    Lingerie Store  Liquor Store  Martial Arts Dojo  Men's Store  \
# 5               0             0                  0            0
# 6               0             0                  0            0
# 7               0             0                  0            0
# 8               0             0                  0            0
# 9               0             0                  0            0
#
#    Mobile Phone Shop  Movie Theater  Music Venue  Nightlife Spot  \
# 5                  0              0            0               0
# 6                  0              0            0               0
# 7                  0              0            0               0
# 8                  0              0            0               0
# 9                  0              0            0               0
#
#    Optical Shop  Pet Store  Pharmacy  Pizza Place  Plaza  Salon / Barbershop  \
# 5             0          0         0            1      0                   0
# 6             0          0         0            0      0                   0
# 7             0          0         0            0      0                   0
# 8             0          0         0            0      0                   0
# 9             0          0         0            0      0                   0
#
#    Sandwich Place  Scenic Lookout  Shoe Store  Shopping Mall  Skating Rink  \
# 5               0               0           0              0             0
# 6               0               0           0              0             0
# 7               0               0           0              0             0
# 8               0               0           0              0             0
# 9               0               0           0              0             0
#
#    Smoke Shop  Smoothie Shop  Snack Place  Spa  Steakhouse  Supermarket  \
# 5           0              0            0    0           0            0
# 6           0              0            0    0           0            0
# 7           0              0            0    0           0            0
# 8           0              0            0    0           0            0
# 9           0              0            0    0           0            0
#
#    Supplement Shop  Taco Place  Tattoo Parlor  Theater  \
# 5                0           0              0        0
# 6                0           0              0        0
# 7                0           0              0        0
# 8                0           0              0        0
# 9                0           0              0        0
#
#    Thrift / Vintage Store  Toy / Game Store  Train Station  Video Game Store  \
# 5                       0                 0              0                 0
# 6                       0                 0              0                 0
# 7                       0                 0              0                 0
# 8                       0                 0              0                 0
# 9                       0                 0              0                 0
#
#    Wine Bar  Wine Shop  Wings Joint  Women's Store  Yoga Studio
# 5         0          0            0              0            0
# 6         0          0            0              0            0
# 7         0          0            0              0            0
# 8         0          0            0              0            0
# 9         0          0            0              0            0

# %%
add_to_keep = ['BBQ Joint', 'Bagel Shop', 'Breakfast Spot', 'Burger Joint', 'Café', 'Coffee Shop', 'Deli / Bodega', 'Diner', 'Food', 'Gastropub', 'Pizza Place', 'Sandwich Place', 'Snack Place', 'Steakhouse', 'Taco Place', 'Wings Joint'] 

for k in add_to_keep:
    keep.append(k)
    
print(keep)
# Out:
# ['American Restaurant', 'Asian Restaurant', 'Chinese Restaurant', 'Fast Food Restaurant', 'French Restaurant', 'Italian Restaurant', 'Japanese Restaurant', 'Mexican Restaurant', 'Middle Eastern Restaurant', 'New American Restaurant', 'Ramen Restaurant', 'Restaurant', 'Seafood Restaurant', 'Sushi Restaurant', 'Tapas Restaurant', 'Tex-Mex Restaurant', 'Vietnamese Restaurant', 'BBQ Joint', 'Bagel Shop', 'Breakfast Spot', 'Burger Joint', 'Café', 'Coffee Shop', 'Deli / Bodega', 'Diner', 'Food', 'Gastropub', 'Pizza Place', 'Sandwich Place', 'Snack Place', 'Steakhouse', 'Taco Place', 'Wings Joint']

# %% [markdown]
# ##### Now we'll drop all other categories from the dataframe.

# %%
keep.append('Neighborhood')
onehot = onehot[keep]

onehot.head()
# Out:
#    American Restaurant  Asian Restaurant  Chinese Restaurant  \
# 5                    0                 0                   0
# 6                    0                 0                   0
# 7                    0                 0                   0
# 8                    0                 0                   0
# 9                    0                 0                   0
#
#    Fast Food Restaurant  French Restaurant  Italian Restaurant  \
# 5                     0                  0                   0
# 6                     0                  0                   0
# 7                     0                  0                   0
# 8                     0                  0                   0
# 9                     0                  0                   0
#
#    Japanese Restaurant  Mexican Restaurant  Middle Eastern Restaurant  \
# 5                    0                   0                          0
# 6                    0                   0                          0
# 7                    1                   0                          0
# 8                    0                   0                          0
# 9                    0                   0                          0
#
#    New American Restaurant  Ramen Restaurant  Restaurant  Seafood Restaurant  \
# 5                        0                 0           0                   0
# 6                        0                 0           0                   0
# 7                        0                 0           0                   0
# 8                        0                 0           0                   0
# 9                        0                 0           0                   0
#
#    Sushi Restaurant  Tapas Restaurant  Tex-Mex Restaurant  \
# 5                 0                 0                   0
# 6                 0                 1                   0
# 7                 0                 0                   0
# 8                 0                 0                   0
# 9                 0                 0                   0
#
#    Vietnamese Restaurant  BBQ Joint  Bagel Shop  Breakfast Spot  Burger Joint  \
# 5                      0          0           0               0             0
# 6                      0          0           0               0             0
# 7                      0          0           0               0             0
# 8                      0          0           0               0             0
# 9                      0          0           0               0             0
#
#    Café  Coffee Shop  Deli / Bodega  Diner  Food  Gastropub  Pizza Place  \
# 5     0            0              0      0     0          0            1
# 6     0            0              0      0     0          0            0
# 7     0            0              0      0     0          0            0
# 8     0            0              0      0     0          0            0
# 9     0            0              0      0     0          0            0
#
#    Sandwich Place  Snack Place  Steakhouse  Taco Place  Wings Joint  \
# 5               0            0           0           0            0
# 6               0            0           0           0            0
# 7               0            0           0           0            0
# 8               0            0           0           0            0
# 9               0            0           0           0            0
#
#       Neighborhood
# 5  Fishkill Plains
# 6  Fishkill Plains
# 7  Fishkill Plains
# 8  Fishkill Plains
# 9  Fishkill Plains

# %% [markdown]
# ##### Now we'll group them by neighborhood and take the mean of occurrence.

# %%
grouped = onehot.groupby('Neighborhood').mean().reset_index()
grouped
# Out:
#        Neighborhood  American Restaurant  Asian Restaurant  \
# 0       Arthursburg             0.000000          0.000000
# 1            Beacon             0.095238          0.023810
# 2          Fishkill             0.030303          0.000000
# 3   Fishkill Plains             0.000000          0.000000
# 4     Knapps Corner             0.000000          0.000000
# 5          Newburgh             0.076923          0.000000
# 6           Pawling             0.000000          0.000000
# 7   Pleasant Valley             0.000000          0.000000
# 4         0.00000           0.0  0.000000     0.019608       0.000000
# 5         0.00000           0.0  0.038462     0.038462       0.000000
# 6         0.00000           0.0  0.000000     0.000000       0.095238
# 7         0.00000           0.0  0.000000     0.000000       0.000000
# 8         0.00000           0.0  0.000000     0.000000       0.055556
# 9         0.00000           0.0  0.000000     0.000000       0.000000
#
#       Diner      Food  Gastropub  Pizza Place  Sandwich Place  Snack Place  \
# 0  0.000000  0.000000   0.000000     0.000000        0.000000     0.000000
# 1  0.023810  0.000000   0.000000     0.047619        0.023810     0.000000
# 2  0.000000  0.000000   0.000000     0.000000        0.030303     0.000000
# 3  0.000000  0.052632   0.000000     0.157895        0.052632     0.000000
# 4  0.000000  0.000000   0.000000     0.000000        0.000000     0.019608
# 5  0.000000  0.038462   0.000000     0.000000        0.000000     0.000000
# 6  0.000000  0.000000   0.047619     0.047619        0.000000     0.000000
# 7  0.000000  0.000000   0.000000     0.125000        0.062500     0.000000
# 8  0.055556  0.000000   0.000000     0.055556        0.055556     0.000000
# 9  0.000000  0.000000   0.000000     0.068966        0.034483     0.000000
#
#    Steakhouse  Taco Place  Wings Joint
# 0    0.000000    0.000000     0.000000
# 1    0.000000    0.000000     0.000000
# 2    0.030303    0.000000     0.000000
# 3    0.000000    0.000000     0.000000
# 4    0.000000    0.000000     0.000000
# 5    0.000000    0.076923     0.000000
# 6    0.000000    0.047619     0.000000
# 7    0.000000    0.000000     0.000000
# 8    0.000000    0.000000     0.000000
# 9    0.000000    0.000000     0.034483

# %%
grouped.shape
# Out:
# (10, 34)

# %% [markdown]
# ##### We'll use the following function in a loop to sort the columns by descending order.

# %%
def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_venues]

# %%
num_top_venues = 10

indicators = ['st', 'nd', 'rd']

# create columns according to number of top venues
columns = ['Neighborhood']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))

# create a new dataframe
venues_sorted = pd.DataFrame(columns=columns)
venues_sorted['Neighborhood'] = grouped['Neighborhood']

for ind in np.arange(grouped.shape[0]):
    venues_sorted.iloc[ind, 1:] = return_most_common_venues(grouped.iloc[ind, :], num_top_venues)

venues_sorted.head()
# Out:
#       Neighborhood 1st Most Common Venue 2nd Most Common Venue  \
# 0      Arthursburg          Burger Joint    Italian Restaurant
# 1           Beacon   American Restaurant           Pizza Place
# 2         Fishkill    Italian Restaurant  Fast Food Restaurant
# 3  Fishkill Plains           Pizza Place    Italian Restaurant
# 4    Knapps Corner    Tex-Mex Restaurant           Coffee Shop
#
#   3rd Most Common Venue 4th Most Common Venue      5th Most Common Venue  \
# 0                  Café           Wings Joint  Middle Eastern Restaurant
# 1                  Café        Breakfast Spot           Asian Restaurant
# 2            Restaurant   American Restaurant                 Bagel Shop
# 3        Sandwich Place  Fast Food Restaurant                       Food
# 4           Snack Place    Italian Restaurant           Sushi Restaurant
#
#   6th Most Common Venue 7th Most Common Venue      8th Most Common Venue  \
# 0    Seafood Restaurant            Restaurant           Ramen Restaurant
# 1      Ramen Restaurant        Sandwich Place  Middle Eastern Restaurant
# 2      Sushi Restaurant        Sandwich Place                 Steakhouse
# 3      Tapas Restaurant   Japanese Restaurant  Middle Eastern Restaurant
# 4    Seafood Restaurant            Restaurant           Ramen Restaurant
#
#      9th Most Common Venue     10th Most Common Venue
# 0  New American Restaurant         Mexican Restaurant
# 1                    Diner         Mexican Restaurant
# 2       Chinese Restaurant          French Restaurant
# 3       Seafood Restaurant                 Restaurant
# 4  New American Restaurant  Middle Eastern Restaurant

# %% [markdown]
# # Cluster Neighborhoods by Restaurant Types Using K-Means

# %%
# set number of clusters
kclusters = 5

grouped_clustering = grouped.drop('Neighborhood', axis = 1)

# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0, n_init = 30).fit(grouped_clustering)

# check cluster labels generated for each row in the dataframe
kmeans.labels_[0:10]
# Out:
# array([2, 0, 3, 1, 0, 4, 0, 1, 0, 0], dtype=int32)

# %% [markdown]
# ##### Now we'll add these cluster labels to the dataframe and plot them with Folium.

# %%
# add clustering labels
venues_sorted.insert(0, 'Cluster Label', kmeans.labels_)

venues_sorted['Latitude'] = ''
venues_sorted['Longitude'] = ''

for index, row in df.iterrows():
    for index2, row2 in venues_sorted.iterrows():
        if row['Neighborhood'] == row2['Neighborhood']:
            venues_sorted.loc[index2, 'Latitude'] = df.loc[index, 'Latitude']
            venues_sorted.loc[index2, 'Longitude'] = df.loc[index, 'Longitude']

# Reorder columns for clarity
venues_sorted = venues_sorted[['Neighborhood', 'Cluster Label', 'Latitude', 'Longitude', '1st Most Common Venue', '2nd Most Common Venue', '3rd Most Common Venue', '4th Most Common Venue', '5th Most Common Venue', '6th Most Common Venue', '7th Most Common Venue', '8th Most Common Venue', '9th Most Common Venue', '10th Most Common Venue']]
venues_sorted.head()
# Out:
#       Neighborhood  Cluster Label Latitude Longitude 1st Most Common Venue  \
# 0      Arthursburg              2  41.6284  -73.7715          Burger Joint
# 1           Beacon              0  41.5049  -73.9697   American Restaurant
# 2         Fishkill              3  41.5356  -73.8987    Italian Restaurant
# 3  Fishkill Plains              1  41.6072  -73.8302           Pizza Place
# 4    Knapps Corner              0  41.6286  -73.9166    Tex-Mex Restaurant
#
#   2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 0    Italian Restaurant                  Café           Wings Joint
# 1           Pizza Place                  Café        Breakfast Spot
# 2  Fast Food Restaurant            Restaurant   American Restaurant
# 3    Italian Restaurant        Sandwich Place  Fast Food Restaurant
# 4           Coffee Shop           Snack Place    Italian Restaurant
#
#        5th Most Common Venue 6th Most Common Venue 7th Most Common Venue  \
# 0  Middle Eastern Restaurant    Seafood Restaurant            Restaurant
# 1           Asian Restaurant      Ramen Restaurant        Sandwich Place
# 2                 Bagel Shop      Sushi Restaurant        Sandwich Place
# 3                       Food      Tapas Restaurant   Japanese Restaurant
# 4           Sushi Restaurant    Seafood Restaurant            Restaurant
#
#        8th Most Common Venue    9th Most Common Venue  \
# 0           Ramen Restaurant  New American Restaurant
# 1  Middle Eastern Restaurant                    Diner
# 2                 Steakhouse       Chinese Restaurant
# 3  Middle Eastern Restaurant       Seafood Restaurant
# 4           Ramen Restaurant  New American Restaurant
#
#       10th Most Common Venue
# 0         Mexican Restaurant
# 1         Mexican Restaurant
# 2          French Restaurant
# 3                 Restaurant
# 4  Middle Eastern Restaurant

# %%
# Create Folium object
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=10.4)

# Set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# Add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(venues_sorted['Latitude'], venues_sorted['Longitude'], venues_sorted['Neighborhood'], venues_sorted['Cluster Label']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ##### Now we've narrowed our search into 10 neighborhoods, each being classified into one of 5 categories. When running the k means with all 89 neighborhoods, the vast majority, almost all of them, were in the cluster shown in red. So, if we want to go somewhere that has the most typical variety of restaurants, which is what we would most likely choose, we've narrowed down our search to only 5 neighborhoods. Of course, we should explore the other areas too. Maybe we'd like the more atypical variety of restaurants more.
